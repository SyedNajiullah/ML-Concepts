# %% [markdown]
# #Importing

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Matplot

# %% [markdown]
# Basic figure simple line ploting using matplot

# %%
x_values = [1, 2, 3, 4, 5]
y_values = [1, 4, 3, 2, 5]
plt.plot(x_values, y_values)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Example Graph")
plt.show()

# %% [markdown]
# Multiple plotting

# %%
x_values = np.linspace(1, 10, 5)
y_values1 = np.sin(x_values)
y_values2 = np.cos(y_values)

plt.plot(x_values, y_values1, label="sin(x)")
plt.plot(x_values, y_values2, label="cos(x)")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend()
plt.title("Sin Cosine curve")
plt.show()

# %% [markdown]
# Scatter plot

# %%
x_values = np.linspace(1, 15, 10)
y_values = np.linspace(1, 45, 10)

plt.scatter(x_values, y_values)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Scatter Plot")
plt.show()

# %% [markdown]
# Colors line width, type

# %%
x_values = np.linspace(0, 10, 20)
y_values1 = np.sin(x_values)
y_values2 = np.cos(x_values)
y_values3 = np.tan(x_values / 2)

plt.plot(x_values, y_values1, label="sin(x)", color="green", linewidth=5, linestyle=":", alpha = 0.7) # Dotted line, alpha = transparence
plt.plot(x_values, y_values2, label="cos(x)", color="red", linewidth=5, linestyle="--", alpha=1) # Dashed line
plt.plot(x_values, y_values3, label="tan(x/2)", color="blue", linewidth=5, linestyle="-", alpha=0.5) # straignt line

plt.legend()
plt.xlim(0, 10)
plt.ylim(-2, 2)

plt.title("Sin Cos Tan")
plt.xlabel("x-axis")
plt.ylabel("y-axis")

plt.show()

# %% [markdown]
# Color scatter plot

# %%
x_values = np.linspace(0, 10, 100)
y_values = np.sin(x_values)
colors_id = np.linspace(0, 1, len(x_values))

plt.scatter(x_values, y_values, c=colors_id, cmap="viridis")
plt.colorbar(label="Colorbar")

plt.show()

# %%
figure, axes = plt.subplots(2, 2, figsize=(8, 8))

x_values = np.linspace(0,10, 10)

axes[0, 0].plot(x_values, np.sin(x_values), "r-")
axes[0, 0].set_xlabel("x-axis")
axes[0, 0].set_ylabel("y-axis")
axes[0, 0].set_title("six(x)")

axes[0, 1].plot(x_values, np.cos(x_values), "g-")
axes[0, 1].set_xlabel("x-axis")
axes[0, 1].set_ylabel("y-axis")
axes[0, 1].set_title("cos(x)")

axes[1, 0].plot(x_values, np.tan(x_values), "b-")
axes[1, 0].set_xlabel("x-axis")
axes[1, 0].set_ylabel("y-axis")
axes[1, 0].set_title("tan(x)")

axes[1, 1].plot(x_values, np.tanh(x_values), "y-")
axes[1, 1].set_xlabel("x-axis")
axes[1, 1].set_ylabel("y-axis")
axes[1, 1].set_title("tanh(x)")

figure.tight_layout()
figure.show()

# %% [markdown]
# Bar graph, Horizontal Bar graph

# %%
x_categories = ["A", "B", "C", "D"]
y_values = [25, 50, 10, 15]

plt.bar(x_categories, y_values, color=["Red", "Green", "Blue", "Yellow"])
plt.xlabel("Categories")
plt.ylabel("Values")
plt.title("Bar Graph")
plt.show()

plt.barh(x_categories, y_values, color=["Red", "Green", "Blue", "Yellow"])
plt.xlabel("Values")
plt.ylabel("Categories")
plt.title("Bar Graph")
plt.show()

# %% [markdown]
# Histograms, Group histogram

# %%
values = [70, 10, 34]
print(values)
plt.hist(values, color="green", alpha = 0.7)
plt.xlabel("x_axis")
plt.ylabel("y_axis")
plt.title("Histogram")
plt.show()


values1 = [1, 5, 3, 2, 1, 2]
values2 = [3, 0, 5, 9, 10, 2]

plt.hist(values1, color="blue", alpha=0.5)
plt.hist(values2, color="red", alpha=0.5)
plt.xlabel("x_axis")
plt.ylabel("y_axis")
plt.title("Grouped Histogram")
plt.show()
# Out:
# [70, 10, 34]

# %% [markdown]
# Pie graph

# %%
pie_values = [10, 25, 10, 15, 40]
pie_categroies = ["A", "B", "C", "D", "E"]
colors = ["Red", "Green", "Blue", "Orange", "Black"]

plt.pie(pie_values, labels=pie_categroies, colors=colors)
plt.title("Pie Graph")
plt.legend()
plt.show()

# %% [markdown]
# Heatmaps

# %%
data = np.array([
    [1, 2, 3], [4, 5, 6]
])

plt.imshow(data, cmap="hot")
plt.colorbar()
plt.title("Heat map")
plt.show()

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
penguins_dataframe = sns.load_dataset("penguins")
penguins_dataframe.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
# Scatter Plot on flipper_length_mm vs body_mass_g grouped by island
sns.scatterplot(data=penguins_dataframe, x="flipper_length_mm", y="body_mass_g", hue = "island")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
# Scatter Plot on flipper_length_mm vs body_mass_g grouped by gender
sns.set_style("ticks") # allowed styles are white, dark, whitegrid, darkgrid, ticks
sns.set_context("notebook") # allowed context are paper, notebook, talk, poster
sns.scatterplot(data=penguins_dataframe, x="flipper_length_mm", y="body_mass_g", hue = "sex")
sns.despine() # removing top and left lines

# %%
sns.scatterplot(data=penguins_dataframe, x="species", y="body_mass_g", hue = "island", style = "sex", alpha=0.7)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.stripplot(data=penguins_dataframe, x="species", y="body_mass_g", hue = "island", dodge = True)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.set_context("notebook")
sns.swarmplot(data=penguins_dataframe, x="species", y="body_mass_g", hue = "island")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.histplot(data=penguins_dataframe, x="body_mass_g", hue="sex", multiple="stack")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
sns.regplot(data=penguins_dataframe, x="body_mass_g", y="flipper_length_mm", color="green")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.lineplot(data=penguins_dataframe, x="body_mass_g", y="flipper_length_mm", hue="island", style="sex")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.jointplot(data=penguins_dataframe, x="body_mass_g", y="flipper_length_mm", kind="reg")
# kind can be of the following (['scatter', 'hist', 'hex', 'kde', 'reg', 'resid'])

# %%
sns.barplot(data=penguins_dataframe, x="species", y="body_mass_g", hue="sex")
# The body mass is average meaning avereage body mass of male species of adelie is around 400. it can be set to sum of mass of all specie
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(data=penguins_dataframe, x="species", y="body_mass_g", hue="sex", estimator=np.sum)
# The body mass is average meaning avereage body mass of male species of adelie is around 400. it can be set to sum as well
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.countplot(data=penguins_dataframe, x="species", hue="island")
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
sns.boxplot(data=penguins_dataframe, x="species", y="body_mass_g", hue="island")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.violinplot(data=penguins_dataframe, x="species", y="body_mass_g", hue="island")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
# Heatmap
columns = ["bill_length_mm", "bill_depth_mm",	"flipper_length_mm",	"body_mass_g"]
print(penguins_dataframe[columns].corr())
sns.heatmap(data=penguins_dataframe[columns].corr(), annot=True, cmap="Blues", vmin=-0.2)
#
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000
# <Axes: >

# %%
sns.rugplot(data=penguins_dataframe, y="body_mass_g", hue="species", height=0.8)
# Out:
# <Axes: ylabel='body_mass_g'>

# %%
sns.pairplot(data=penguins_dataframe[columns], palette="Set2")
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# ...

# %%
df = pd.read_csv('/content/HistoricalData.csv')
df.head()
# Out:
#          Date Close/Last    Volume      Open     High      Low
# 0  11/03/2025    $269.05  50194580   $270.42  $270.85  $266.25
# 1  10/31/2025    $270.37  86167120   $276.99  $277.32  $269.16
# 2  10/30/2025    $271.40  69886530   $271.99  $274.14  $268.48
# 3  10/29/2025    $269.70  51086740  $269.275  $271.41  $267.11
# 4  10/28/2025    $269.00  41534760  $268.985  $269.89  $268.15

# %%
fig = px.bar(df, x="Date", y="Close/Last")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter_3d(df, x="Date", y="Close/Last", z="Volume")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
x_values = [1, 2, 3, 4, 5]
y_values = [1, 4, 3, 2, 5]
y_values1 = [1, 3, 1, 4, 7]
fig = px.line(df, x=x_values, y=[y_values, y_values1], title="Interactive Line chart")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(df, x="Date", y="Close/Last")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df, x='Date', y='Close/Last', title='My First Bar Chart')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df2 = px.data.tips()
fig = px.histogram(df2, x="total_bill")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df, x='Close/Last', y='Date', orientation='h', title='My First horizontal Bar Chart')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
x_values = [1, 2, 3, 4, 5]
y_values = [1, 4, 3, 2, 5]
z_values = [5, 3, 1, 6, 4]
group = ["A", "A", "B", "B", "A"]

fig = px.scatter_3d(x=x_values, y=y_values, z=z_values, color=group)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
values = [30, 45, 25]
labels = ['Apples', 'Bananas', 'Cherries']
fig = px.pie(names=labels, values=values, title='Fruit Distribution',
    hole=0
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
values = [30, 45, 25]
labels = ['Apples', 'Bananas', 'Cherries']
fig = px.pie(names=labels, values=values, title='Fruit Distribution',
    hole=0.4
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = {
    'Category': ['A', 'A', 'A', 'B', 'B', 'B', 'C', 'C', 'C'],
    'Values': [10, 12, 15, 18, 20, 22, 14, 16, 19]
}

fig = px.box(data_frame=data, x='Category', y='Values', title='Basic Box Plot')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

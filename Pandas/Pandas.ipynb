# %%
import pandas as pd
import os

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
list_s = [1, 2, -3, 6.2, "data values"]
list_s
# Out:
# [1, 2, -3, 6.2, 'data values']

# %%
series1 = pd.Series(list_s)

# %%
type(series1)
# Out:
# pandas.core.series.Series

# %%
series2 = pd.Series([1, 2, 3, 4])
series2
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
empty_s = pd.Series([])
empty_s
# Out:
# Series([], dtype: object)

# %%
series3 = pd.Series([1, 2, 3, 4], index=["a", "b", "c", "d"])
series3
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
series4 = pd.Series([1, 2, 3, 4], index=["a", "b", "c", "d"],name="data values", dtype=float)
series4
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# Name: data values, dtype: float64

# %%
scalar_s = pd.Series(0.5)
scalar_s
# Out:
# 0    0.5
# dtype: float64

# %%
scalar_s = pd.Series(0.5, index=[1, 2, 3])
scalar_s
# Out:
# 1    0.5
# 2    0.5
# 3    0.5
# dtype: float64

# %%
dict_s = pd.Series({"a": 1, "b": 2})
dict_s
# Out:
# a    1
# b    2
# dtype: int64

# %%
s4 = pd.Series([1, 2, 3, 4, 5])
s4
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s4[0]
# Out:
# np.int64(1)

# %%
s4[3]
# Out:
# np.int64(4)

# %%
s4[0:3] # slicing
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
max(s4)
# Out:
# 5

# %%
min(s4)
# Out:
# 1

# %%
(s4 > 3)
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# dtype: bool

# %%
s4[s4 > 3]
# Out:
# 3    4
# 4    5
# dtype: int64

# %%
s5 = pd.Series([1, 2, 3, 4, 5])
s5
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s4 + s5
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64

# %%
s6 = pd.Series([1, 2, 3])
s6
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
s5 + s6 # missing values
# Out:
# 0    2.0
# 1    4.0
# 2    6.0
# 3    NaN
# 4    NaN
# dtype: float64

# %%
emt_df = pd.DataFrame()
emt_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
lst = ["a", "b", "c"]
lst
# Out:
# ['a', 'b', 'c']

# %%
df1 = pd.DataFrame(lst)
df1
# Out:
#    0
# 0  a
# 1  b
# 2  c

# %%
ls_of_ls = [[1, 2, 3], [2, 3, 4], [4, 5, 6]]
ls_of_ls
# Out:
# [[1, 2, 3], [2, 3, 4], [4, 5, 6]]

# %%
df2 = pd.DataFrame(ls_of_ls)
df2
# Out:
#    0  1  2
# 0  1  2  3
# 1  2  3  4
# 2  4  5  6

# %%
dict1 = {"ID": [11, 22, 33, 44]}
dict1
# Out:
# {'ID': [11, 22, 33, 44]}

# %%
df3 = pd.DataFrame(dict1)
df3
# Out:
#    ID
# 0  11
# 1  22
# 2  33
# 3  44

# %%
dict1 = {"ID": [11, 22, 33, 44], "SN": [1, 2, 3, 4]}
dict1
# Out:
# {'ID': [11, 22, 33, 44], 'SN': [1, 2, 3, 4]}

# %%
df3 = pd.DataFrame(dict1)
df3
# Out:
#    ID  SN
# 0  11   1
# 1  22   2
# 2  33   3
# 3  44   4

# %%
ls_dict = [{"a":1, "b":2},{"a":3, "b":4, "c":5}]
df5 = pd.DataFrame(ls_dict)
df5
# Out:
#    a  b    c
# 0  1  2  NaN
# 1  3  4  5.0

# %%
dict_sr = {"id": pd.Series([1, 2, 3]), "sn": pd.Series([111, 222, 333])}
df6 = pd.DataFrame(dict_sr)
df6
# Out:
#    id   sn
# 0   1  111
# 1   2  222
# 2   3  333

# %%
df = pd.read_excel("/content/SalaryPrediction.xlsx")
df
# Out:
#        company                  job     degree  sallary_more_then_100k
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       0
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4       google  computer programmer  bachelors                       0
# 5       google  computer programmer    masters                       1
# 6   abc pharma      sales executive    masters                       0
# 7   abc pharma  computer programmer  bachelors                       0
# 8   abc pharma     business manager  bachelors                       0
# 9   abc pharma     business manager    masters                       1
# 10    facebook      sales executive  bachelors                       1
# 11    facebook      sales executive    masters                       1
# ...

# %%
# df = pd.read_csv("/content/SalaryPrediction.xlsx")
# df

# %%
print(os.getcwd())
# Out:
# /content

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['company', 'job', 'degree', 'sallary_more_then_100k'], dtype='object')

# %%
# taking only 5 rows
df = pd.read_excel("/content/SalaryPrediction.xlsx", nrows=10)
df
# Out:
#       company                  job     degree  sallary_more_then_100k
# 0      google      sales executive  bachelors                       0
# 1      google      sales executive    masters                       0
# 2      google     business manager  bachelors                       1
# 3      google     business manager    masters                       1
# 4      google  computer programmer  bachelors                       0
# 5      google  computer programmer    masters                       1
# 6  abc pharma      sales executive    masters                       0
# 7  abc pharma  computer programmer  bachelors                       0
# 8  abc pharma     business manager  bachelors                       0
# 9  abc pharma     business manager    masters                       1

# %%
# taking only 5 rows
df = pd.read_excel("/content/SalaryPrediction.xlsx", usecols=[0,1,2,3])
df
# Out:
#        company                  job     degree  sallary_more_then_100k
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       0
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4       google  computer programmer  bachelors                       0
# 5       google  computer programmer    masters                       1
# 6   abc pharma      sales executive    masters                       0
# 7   abc pharma  computer programmer  bachelors                       0
# 8   abc pharma     business manager  bachelors                       0
# 9   abc pharma     business manager    masters                       1
# 10    facebook      sales executive  bachelors                       1
# 11    facebook      sales executive    masters                       1
# ...

# %%
# skiping first 5 rows
df = pd.read_excel("/content/SalaryPrediction.xlsx", skiprows=5)
df
# Out:
#         google  computer programmer  bachelors  0
# 0       google  computer programmer    masters  1
# 1   abc pharma      sales executive    masters  0
# 2   abc pharma  computer programmer  bachelors  0
# 3   abc pharma     business manager  bachelors  0
# 4   abc pharma     business manager    masters  1
# 5     facebook      sales executive  bachelors  1
# 6     facebook      sales executive    masters  1
# 7     facebook     business manager  bachelors  1
# 8     facebook     business manager    masters  1
# 9     facebook  computer programmer  bachelors  1
# 10    facebook  computer programmer    masters  1

# %%
# skiping first 5th rows
df = pd.read_excel("/content/SalaryPrediction.xlsx", skiprows=[5])
df
# Out:
#        company                  job     degree  sallary_more_then_100k
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       0
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4       google  computer programmer    masters                       1
# 5   abc pharma      sales executive    masters                       0
# 6   abc pharma  computer programmer  bachelors                       0
# 7   abc pharma     business manager  bachelors                       0
# 8   abc pharma     business manager    masters                       1
# 9     facebook      sales executive  bachelors                       1
# 10    facebook      sales executive    masters                       1
# 11    facebook     business manager  bachelors                       1
# ...

# %%
df = pd.read_excel("/content/SalaryPrediction.xlsx", index_col="company")
df
# Out:
#                             job     degree  sallary_more_then_100k
# company
# google          sales executive  bachelors                       0
# google          sales executive    masters                       0
# google         business manager  bachelors                       1
# google         business manager    masters                       1
# google      computer programmer  bachelors                       0
# google      computer programmer    masters                       1
# abc pharma      sales executive    masters                       0
# abc pharma  computer programmer  bachelors                       0
# abc pharma     business manager  bachelors                       0
# abc pharma     business manager    masters                       1
# facebook        sales executive  bachelors                       1
# facebook        sales executive    masters                       1
# facebook       business manager  bachelors                       1
# ...

# %%
# first col
df = pd.read_excel("/content/SalaryPrediction.xlsx", index_col=1)
df
# Out:
#                         company     degree  sallary_more_then_100k
# job
# sales executive          google  bachelors                       0
# sales executive          google    masters                       0
# business manager         google  bachelors                       1
# business manager         google    masters                       1
# computer programmer      google  bachelors                       0
# computer programmer      google    masters                       1
# sales executive      abc pharma    masters                       0
# computer programmer  abc pharma  bachelors                       0
# business manager     abc pharma  bachelors                       0
# business manager     abc pharma    masters                       1
# sales executive        facebook  bachelors                       1
# sales executive        facebook    masters                       1
# business manager       facebook  bachelors                       1
# ...

# %%
df = pd.read_excel("/content/SalaryPrediction.xlsx", header=None)
df
# Out:
#              0                    1          2                       3
# 0      company                  job     degree  sallary_more_then_100k
# 1       google      sales executive  bachelors                       0
# 2       google      sales executive    masters                       0
# 3       google     business manager  bachelors                       1
# 4       google     business manager    masters                       1
# 5       google  computer programmer  bachelors                       0
# 6       google  computer programmer    masters                       1
# 7   abc pharma      sales executive    masters                       0
# 8   abc pharma  computer programmer  bachelors                       0
# 9   abc pharma     business manager  bachelors                       0
# 10  abc pharma     business manager    masters                       1
# 11    facebook      sales executive  bachelors                       1
# ...

# %%
df = pd.read_excel("/content/SalaryPrediction.xlsx", names = ["company", "position", "degree", "salary100Kmore"])
df
# Out:
#        company             position     degree  salary100Kmore
# 0       google      sales executive  bachelors               0
# 1       google      sales executive    masters               0
# 2       google     business manager  bachelors               1
# 3       google     business manager    masters               1
# 4       google  computer programmer  bachelors               0
# 5       google  computer programmer    masters               1
# 6   abc pharma      sales executive    masters               0
# 7   abc pharma  computer programmer  bachelors               0
# 8   abc pharma     business manager  bachelors               0
# 9   abc pharma     business manager    masters               1
# 10    facebook      sales executive  bachelors               1
# 11    facebook      sales executive    masters               1
# 12    facebook     business manager  bachelors               1
# 13    facebook     business manager    masters               1
# ...

# %%
df.head()
# Out:
#   company             position     degree  salary100Kmore
# 0  google      sales executive  bachelors               0
# 1  google      sales executive    masters               0
# 2  google     business manager  bachelors               1
# 3  google     business manager    masters               1
# 4  google  computer programmer  bachelors               0

# %%
df.head(8)
# Out:
#       company             position     degree  salary100Kmore
# 0      google      sales executive  bachelors               0
# 1      google      sales executive    masters               0
# 2      google     business manager  bachelors               1
# 3      google     business manager    masters               1
# 4      google  computer programmer  bachelors               0
# 5      google  computer programmer    masters               1
# 6  abc pharma      sales executive    masters               0
# 7  abc pharma  computer programmer  bachelors               0

# %%
df.tail()
# Out:
#      company             position     degree  salary100Kmore
# 11  facebook      sales executive    masters               1
# 12  facebook     business manager  bachelors               1
# 13  facebook     business manager    masters               1
# 14  facebook  computer programmer  bachelors               1
# 15  facebook  computer programmer    masters               1

# %%
df.tail(9)
# Out:
#        company             position     degree  salary100Kmore
# 7   abc pharma  computer programmer  bachelors               0
# 8   abc pharma     business manager  bachelors               0
# 9   abc pharma     business manager    masters               1
# 10    facebook      sales executive  bachelors               1
# 11    facebook      sales executive    masters               1
# 12    facebook     business manager  bachelors               1
# 13    facebook     business manager    masters               1
# 14    facebook  computer programmer  bachelors               1
# 15    facebook  computer programmer    masters               1

# %%
df = pd.read_excel("/content/SalaryPrediction.xlsx", dtype={"salary100Kmore": "float64"})
df
# Out:
#        company                  job     degree  sallary_more_then_100k
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       0
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4       google  computer programmer  bachelors                       0
# 5       google  computer programmer    masters                       1
# 6   abc pharma      sales executive    masters                       0
# 7   abc pharma  computer programmer  bachelors                       0
# 8   abc pharma     business manager  bachelors                       0
# 9   abc pharma     business manager    masters                       1
# 10    facebook      sales executive  bachelors                       1
# 11    facebook      sales executive    masters                       1
# ...

# %%
df = pd.read_excel("/content/SalaryPrediction.xlsx", na_values="not available")
df
# Out:
#        company                  job     degree  sallary_more_then_100k
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       0
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4          NaN  computer programmer  bachelors                       0
# 5          NaN  computer programmer    masters                       1
# 6          NaN      sales executive    masters                       0
# 7          NaN  computer programmer  bachelors                       0
# 8   abc pharma     business manager        NaN                       0
# 9   abc pharma     business manager        NaN                       1
# 10    facebook      sales executive        NaN                       1
# 11    facebook      sales executive        NaN                       1
# ...

# %%
df = pd.read_excel("/content/SalaryPrediction.xlsx", na_values={"company":"not available", "degree":"not available"})
df
# Out:
#        company                  job     degree  sallary_more_then_100k
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       0
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4          NaN  computer programmer  bachelors                       0
# 5          NaN  computer programmer    masters                       1
# 6          NaN      sales executive    masters                       0
# 7          NaN  computer programmer  bachelors                       0
# 8   abc pharma     business manager        NaN                       0
# 9   abc pharma     business manager        NaN                       1
# 10    facebook      sales executive        NaN                       1
# 11    facebook      sales executive        NaN                       1
# ...

# %%
df = pd.read_excel("/content/SalaryPrediction.xlsx", keep_default_na=False)
df
# Out:
#           company                  job         degree  sallary_more_then_100k
# 0          google      sales executive      bachelors                       0
# 1          google      sales executive        masters                       0
# 2          google     business manager      bachelors                       1
# 3          google     business manager        masters                       1
# 4                  computer programmer      bachelors                       0
# 5   not available  computer programmer        masters                       1
# 6                      sales executive        masters                       0
# 7                  computer programmer      bachelors                       0
# 8      abc pharma     business manager                                      0
# 9      abc pharma     business manager                                      1
# 10       facebook      sales executive  not available                       1
# ...

# %%
df = pd.read_excel("/content/SalaryPrediction.xlsx")
df.head()
# Out:
#   company                  job     degree  sallary_more_then_100k
# 0  google      sales executive  bachelors                       0
# 1  google      sales executive    masters                       0
# 2  google     business manager  bachelors                       1
# 3  google     business manager    masters                       1
# 4     NaN  computer programmer  bachelors                       0

# %%
df.isnull()
# Out:
#     company    job  degree  sallary_more_then_100k
# 0     False  False   False                   False
# 1     False  False   False                   False
# 2     False  False   False                   False
# 3     False  False   False                   False
# 4      True  False   False                   False
# 5     False  False   False                   False
# 6      True  False   False                   False
# 7      True  False   False                   False
# 8     False  False    True                   False
# 9     False  False    True                   False
# 10    False  False   False                   False
# 11    False  False    True                   False
# 12    False  False   False                   False
# 13    False  False   False                   False
# 14    False  False   False                   False
# 15    False  False   False                   False

# %%
df.isnull().sum()
# Out:
# company                   3
# job                       0
# degree                    3
# sallary_more_then_100k    0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(6)

# %%
df.notnull()
# Out:
#     company   job  degree  sallary_more_then_100k
# 0      True  True    True                    True
# 1      True  True    True                    True
# 2      True  True    True                    True
# 3      True  True    True                    True
# 4     False  True    True                    True
# 5      True  True    True                    True
# 6     False  True    True                    True
# 7     False  True    True                    True
# 8      True  True   False                    True
# 9      True  True   False                    True
# 10     True  True    True                    True
# 11     True  True   False                    True
# 12     True  True    True                    True
# 13     True  True    True                    True
# 14     True  True    True                    True
# 15     True  True    True                    True

# %%
df.notnull().sum()
# Out:
# company                   13
# job                       16
# degree                    13
# sallary_more_then_100k    16
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# np.int64(58)

# %%
df.dropna() # droping null values
# Out:
#           company                  job         degree  sallary_more_then_100k
# 0          google      sales executive      bachelors                       0
# 1          google      sales executive        masters                       0
# 2          google     business manager      bachelors                       1
# 3          google     business manager        masters                       1
# 5   not available  computer programmer        masters                       1
# 10       facebook      sales executive  not available                       1
# 12       facebook     business manager      bachelors                       1
# 13       facebook     business manager        masters                       1
# 14       facebook  computer programmer      bachelors                       1
# 15       facebook  computer programmer        masters                       1

# %%
df.dropna(axis="columns") # droping columns of null values
# Out:
#                     job  sallary_more_then_100k
# 0       sales executive                       0
# 1       sales executive                       0
# 2      business manager                       1
# 3      business manager                       1
# 4   computer programmer                       0
# 5   computer programmer                       1
# 6       sales executive                       0
# 7   computer programmer                       0
# 8      business manager                       0
# 9      business manager                       1
# 10      sales executive                       1
# 11      sales executive                       1
# 12     business manager                       1
# 13     business manager                       1
# 14  computer programmer                       1
# 15  computer programmer                       1

# %%
df.dropna(how="any")
# Out:
#           company                  job         degree  sallary_more_then_100k
# 0          google      sales executive      bachelors                       0
# 1          google      sales executive        masters                       0
# 2          google     business manager      bachelors                       1
# 3          google     business manager        masters                       1
# 5   not available  computer programmer        masters                       1
# 10       facebook      sales executive  not available                       1
# 12       facebook     business manager      bachelors                       1
# 13       facebook     business manager        masters                       1
# 14       facebook  computer programmer      bachelors                       1
# 15       facebook  computer programmer        masters                       1

# %%
df.dropna(axis=1, how="any")
# Out:
#                     job  sallary_more_then_100k
# 0       sales executive                       0
# 1       sales executive                       0
# 2      business manager                       1
# 3      business manager                       1
# 4   computer programmer                       0
# 5   computer programmer                       1
# 6       sales executive                       0
# 7   computer programmer                       0
# 8      business manager                       0
# 9      business manager                       1
# 10      sales executive                       1
# 11      sales executive                       1
# 12     business manager                       1
# 13     business manager                       1
# 14  computer programmer                       1
# 15  computer programmer                       1

# %%
df.dropna(how="all") # all means row with all Nan values
# Out:
#           company                  job         degree  sallary_more_then_100k
# 0          google      sales executive      bachelors                       0
# 1          google      sales executive        masters                       0
# 2          google     business manager      bachelors                       1
# 3          google     business manager        masters                       1
# 4             NaN  computer programmer      bachelors                       0
# 5   not available  computer programmer        masters                       1
# 6             NaN      sales executive        masters                       0
# 7             NaN  computer programmer      bachelors                       0
# 8      abc pharma     business manager            NaN                       0
# 9      abc pharma     business manager            NaN                       1
# 10       facebook      sales executive  not available                       1
# ...

# %%
df.dropna(thresh=4)
# Out:
#           company                  job         degree  sallary_more_then_100k
# 0          google      sales executive      bachelors                       0
# 1          google      sales executive        masters                       0
# 2          google     business manager      bachelors                       1
# 3          google     business manager        masters                       1
# 5   not available  computer programmer        masters                       1
# 10       facebook      sales executive  not available                       1
# 12       facebook     business manager      bachelors                       1
# 13       facebook     business manager        masters                       1
# 14       facebook  computer programmer      bachelors                       1
# 15       facebook  computer programmer        masters                       1

# %%
df.dropna(subset=["company"])
# Out:
#           company                  job         degree  sallary_more_then_100k
# 0          google      sales executive      bachelors                       0
# 1          google      sales executive        masters                       0
# 2          google     business manager      bachelors                       1
# 3          google     business manager        masters                       1
# 5   not available  computer programmer        masters                       1
# 8      abc pharma     business manager            NaN                       0
# 9      abc pharma     business manager            NaN                       1
# 10       facebook      sales executive  not available                       1
# 11       facebook      sales executive            NaN                       1
# 12       facebook     business manager      bachelors                       1
# 13       facebook     business manager        masters                       1
# ...

# %%
df = pd.read_excel("/content/SalaryPrediction.xlsx", na_values="not available")
df
# Out:
#        company                  job     degree  sallary_more_then_100k
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       0
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4          NaN  computer programmer  bachelors                       0
# 5          NaN  computer programmer    masters                       1
# 6          NaN      sales executive    masters                       0
# 7          NaN  computer programmer  bachelors                       0
# 8   abc pharma     business manager        NaN                       0
# 9   abc pharma     business manager        NaN                       1
# 10    facebook      sales executive        NaN                       1
# 11    facebook      sales executive        NaN                       1
# ...

# %%
df.fillna(0)
# Out:
#        company                  job     degree  sallary_more_then_100k
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       0
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4            0  computer programmer  bachelors                       0
# 5            0  computer programmer    masters                       1
# 6            0      sales executive    masters                       0
# 7            0  computer programmer  bachelors                       0
# 8   abc pharma     business manager          0                       0
# 9   abc pharma     business manager          0                       1
# 10    facebook      sales executive          0                       1
# 11    facebook      sales executive          0                       1
# ...

# %%
df.fillna(2)
# Out:
#        company                  job     degree  sallary_more_then_100k
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       0
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4            2  computer programmer  bachelors                       0
# 5            2  computer programmer    masters                       1
# 6            2      sales executive    masters                       0
# 7            2  computer programmer  bachelors                       0
# 8   abc pharma     business manager          2                       0
# 9   abc pharma     business manager          2                       1
# 10    facebook      sales executive          2                       1
# 11    facebook      sales executive          2                       1
# ...

# %%
df.fillna({"company":"none", "degree":"none"})
# Out:
#        company                  job     degree  sallary_more_then_100k
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       0
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4         none  computer programmer  bachelors                       0
# 5         none  computer programmer    masters                       1
# 6         none      sales executive    masters                       0
# 7         none  computer programmer  bachelors                       0
# 8   abc pharma     business manager       none                       0
# 9   abc pharma     business manager       none                       1
# 10    facebook      sales executive       none                       1
# 11    facebook      sales executive       none                       1
# ...

# %%
df.fillna(method="ffill")
# Out:
# /tmp/ipython-input-3944122520.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill")
#        company                  job     degree  sallary_more_then_100k
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       0
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4       google  computer programmer  bachelors                       0
# 5       google  computer programmer    masters                       1
# 6       google      sales executive    masters                       0
# 7       google  computer programmer  bachelors                       0
# 8   abc pharma     business manager  bachelors                       0
# ...

# %%
df.fillna(method="bfill")
# Out:
# /tmp/ipython-input-3896554658.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="bfill")
#        company                  job     degree  sallary_more_then_100k
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       0
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4   abc pharma  computer programmer  bachelors                       0
# 5   abc pharma  computer programmer    masters                       1
# 6   abc pharma      sales executive    masters                       0
# 7   abc pharma  computer programmer  bachelors                       0
# 8   abc pharma     business manager  bachelors                       0
# ...

# %%
df.fillna(axis=0, method="bfill")
# Out:
# /tmp/ipython-input-3443197980.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(axis=0, method="bfill")
#        company                  job     degree  sallary_more_then_100k
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       0
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4   abc pharma  computer programmer  bachelors                       0
# 5   abc pharma  computer programmer    masters                       1
# 6   abc pharma      sales executive    masters                       0
# 7   abc pharma  computer programmer  bachelors                       0
# 8   abc pharma     business manager  bachelors                       0
# ...

# %%
df.fillna(axis=0, method="ffill")
# Out:
# /tmp/ipython-input-1091048689.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(axis=0, method="ffill")
#        company                  job     degree  sallary_more_then_100k
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       0
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4       google  computer programmer  bachelors                       0
# 5       google  computer programmer    masters                       1
# 6       google      sales executive    masters                       0
# 7       google  computer programmer  bachelors                       0
# 8   abc pharma     business manager  bachelors                       0
# ...

# %%
df.fillna(0, limit=1)
# Out:
#        company                  job     degree  sallary_more_then_100k
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       0
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4            0  computer programmer  bachelors                       0
# 5          NaN  computer programmer    masters                       1
# 6          NaN      sales executive    masters                       0
# 7          NaN  computer programmer  bachelors                       0
# 8   abc pharma     business manager          0                       0
# 9   abc pharma     business manager        NaN                       1
# 10    facebook      sales executive        NaN                       1
# 11    facebook      sales executive        NaN                       1
# ...

# %%
df.replace("not available", "none")
# Out:
#        company                  job     degree  sallary_more_then_100k
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       0
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4          NaN  computer programmer  bachelors                       0
# 5          NaN  computer programmer    masters                       1
# 6          NaN      sales executive    masters                       0
# 7          NaN  computer programmer  bachelors                       0
# 8   abc pharma     business manager        NaN                       0
# 9   abc pharma     business manager        NaN                       1
# 10    facebook      sales executive        NaN                       1
# 11    facebook      sales executive        NaN                       1
# ...

# %%
df["degree"].replace("not available", "none")
# Out:
# 0     bachelors
# 1       masters
# 2     bachelors
# 3       masters
# 4     bachelors
# 5       masters
# 6       masters
# 7     bachelors
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12    bachelors
# 13      masters
# 14    bachelors
# 15      masters
# Name: degree, dtype: object

# %%
df.replace(0, method="bfill", limit=1)
# Out:
# /tmp/ipython-input-1713142884.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   df.replace(0, method="bfill", limit=1)
#        company                  job     degree  sallary_more_then_100k
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       1
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4          NaN  computer programmer  bachelors                       1
# 5          NaN  computer programmer    masters                       1
# 6          NaN      sales executive    masters                       0
# 7          NaN  computer programmer  bachelors                       0
# 8   abc pharma     business manager        NaN                       1
# 9   abc pharma     business manager        NaN                       1
# ...

# %%
df.interpolate() # only works for numeric values
# Out:
# /tmp/ipython-input-4002874584.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate()
#        company                  job     degree  sallary_more_then_100k
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       0
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4          NaN  computer programmer  bachelors                       0
# 5          NaN  computer programmer    masters                       1
# 6          NaN      sales executive    masters                       0
# 7          NaN  computer programmer  bachelors                       0
# 8   abc pharma     business manager        NaN                       0
# ...

# %%
df = pd.read_excel("/content/SalaryPrediction.xlsx", na_values="not available")
df
# Out:
#        company                  job     degree  sallary_more_then_100k  \
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       0
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4          NaN  computer programmer  bachelors                       0
# 5          NaN  computer programmer    masters                       1
# 6          NaN      sales executive    masters                       0
# 7          NaN  computer programmer  bachelors                       0
# 8   abc pharma     business manager        NaN                       0
# 9   abc pharma     business manager        NaN                       1
# 10    facebook      sales executive        NaN                       1
# 11    facebook      sales executive        NaN                       1
# ...

# %%
# df.interpolate(method="time") # prediction for time

# %%
df.interpolate(method="index") # fill null values according to index values
# Out:
# /tmp/ipython-input-3212616353.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method="index") # fill null values according to index values
#        company                  job     degree  sallary_more_then_100k  \
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       0
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4          NaN  computer programmer  bachelors                       0
# 5          NaN  computer programmer    masters                       1
# 6          NaN      sales executive    masters                       0
# 7          NaN  computer programmer  bachelors                       0
# ...

# %%
df.interpolate(method="nearest") # works for numeric data only
# Out:
# /tmp/ipython-input-2965684338.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method="nearest") # works for numeric data only
#        company                  job     degree  sallary_more_then_100k  \
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       0
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4          NaN  computer programmer  bachelors                       0
# 5          NaN  computer programmer    masters                       1
# 6          NaN      sales executive    masters                       0
# 7          NaN  computer programmer  bachelors                       0
# ...

# %%
# df.interpolate(axis=1) # works only if all the column datatype is numeric

# %%
df.interpolate(limit=1) # maximum number of consequitive NAN value to fill
# Out:
# /tmp/ipython-input-2256427613.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(limit=1) # maximum number of consequitive NAN value to fill
#        company                  job     degree  sallary_more_then_100k  \
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       0
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4          NaN  computer programmer  bachelors                       0
# 5          NaN  computer programmer    masters                       1
# 6          NaN      sales executive    masters                       0
# 7          NaN  computer programmer  bachelors                       0
# ...

# %%
df.interpolate(limit=2) # maximum number of consequitive NAN value to fill
# Out:
# /tmp/ipython-input-3312714589.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(limit=2) # maximum number of consequitive NAN value to fill
#        company                  job     degree  sallary_more_then_100k  \
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       0
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4          NaN  computer programmer  bachelors                       0
# 5          NaN  computer programmer    masters                       1
# 6          NaN      sales executive    masters                       0
# 7          NaN  computer programmer  bachelors                       0
# ...

# %%
df.interpolate(limit=1, limit_direction="backward")
# Out:
# /tmp/ipython-input-107589631.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(limit=1, limit_direction="backward")
#        company                  job     degree  sallary_more_then_100k  \
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       0
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4          NaN  computer programmer  bachelors                       0
# 5          NaN  computer programmer    masters                       1
# 6          NaN      sales executive    masters                       0
# 7          NaN  computer programmer  bachelors                       0
# 8   abc pharma     business manager        NaN                       0
# ...

# %%
df.interpolate(limit=1, limit_direction="both") # forward + backward
# Out:
# /tmp/ipython-input-2391899981.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(limit=1, limit_direction="both") # forward + backward
#        company                  job     degree  sallary_more_then_100k  \
# 0       google      sales executive  bachelors                       0
# 1       google      sales executive    masters                       0
# 2       google     business manager  bachelors                       1
# 3       google     business manager    masters                       1
# 4          NaN  computer programmer  bachelors                       0
# 5          NaN  computer programmer    masters                       1
# 6          NaN      sales executive    masters                       0
# 7          NaN  computer programmer  bachelors                       0
# ...

# %%
df.loc[0]
# Out:
# company                            google
# job                       sales executive
# degree                          bachelors
# sallary_more_then_100k                  0
# numeric                               1.0
# Name: 0, dtype: object

# %%
df.loc[8]
# Out:
# company                         abc pharma
# job                       business manager
# degree                                 NaN
# sallary_more_then_100k                   0
# numeric                                0.0
# Name: 8, dtype: object

# %%
df.loc[[0, 1, 2, 3, 4]]
# Out:
#   company                  job     degree  sallary_more_then_100k  numeric
# 0  google      sales executive  bachelors                       0      1.0
# 1  google      sales executive    masters                       0      1.0
# 2  google     business manager  bachelors                       1      1.0
# 3  google     business manager    masters                       1      1.0
# 4     NaN  computer programmer  bachelors                       0      NaN

# %%
df.loc[3, "job"]
# Out:
# 'business manager'

# %%
df.loc[0:3]
# Out:
#   company               job     degree  sallary_more_then_100k  numeric
# 0  google   sales executive  bachelors                       0      1.0
# 1  google   sales executive    masters                       0      1.0
# 2  google  business manager  bachelors                       1      1.0
# 3  google  business manager    masters                       1      1.0

# %%
df.loc[0:3, "job"]
# Out:
# 0     sales executive
# 1     sales executive
# 2    business manager
# 3    business manager
# Name: job, dtype: object

# %%
df["job"] == "sales executive"
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# Name: job, dtype: bool

# %%
df.loc[df["job"] == "sales executive"]
# Out:
#      company              job     degree  sallary_more_then_100k  numeric
# 0     google  sales executive  bachelors                       0      1.0
# 1     google  sales executive    masters                       0      1.0
# 6        NaN  sales executive    masters                       0      NaN
# 10  facebook  sales executive        NaN                       1      0.0
# 11  facebook  sales executive        NaN                       1      NaN

# %%
df.iloc[0]
# Out:
# company                            google
# job                       sales executive
# degree                          bachelors
# sallary_more_then_100k                  0
# numeric                               1.0
# Name: 0, dtype: object

# %%
df.iloc[0:5]
# Out:
#   company                  job     degree  sallary_more_then_100k  numeric
# 0  google      sales executive  bachelors                       0      1.0
# 1  google      sales executive    masters                       0      1.0
# 2  google     business manager  bachelors                       1      1.0
# 3  google     business manager    masters                       1      1.0
# 4     NaN  computer programmer  bachelors                       0      NaN

# %%
df.iloc[0:5, 0]
# Out:
# 0    google
# 1    google
# 2    google
# 3    google
# 4       NaN
# Name: company, dtype: object

# %%
gr1 = df.groupby("company")
gr1.groups
# Out:
# {'abc pharma': [8, 9], 'facebook': [10, 11, 12, 13, 14, 15], 'google': [0, 1, 2, 3]}

# %%
gr2 = df.groupby(["company", "degree"])
gr2.groups
# Out:
# {('abc pharma', nan): [8, 9], ('facebook', 'bachelors'): [12, 14], ('facebook', 'masters'): [13, 15], ('facebook', nan): [10, 11], ('google', 'bachelors'): [0, 2], ('google', 'masters'): [1, 3], (nan, 'bachelors'): [4, 7], (nan, 'masters'): [5, 6]}

# %%
for section, df_1 in gr1:
  print(section)
  print(df_1)
# Out:
# abc pharma
#       company               job degree  sallary_more_then_100k  numeric
# 8  abc pharma  business manager    NaN                       0      0.0
# 9  abc pharma  business manager    NaN                       1      0.0
# facebook
#      company                  job     degree  sallary_more_then_100k  numeric
# 10  facebook      sales executive        NaN                       1      0.0
# 11  facebook      sales executive        NaN                       1      NaN
# 12  facebook     business manager  bachelors                       1      1.0
# 13  facebook     business manager    masters                       1      0.0
# 14  facebook  computer programmer  bachelors                       1      0.0
# 15  facebook  computer programmer    masters                       1      1.0
# google
#   company               job     degree  sallary_more_then_100k  numeric
# 0  google   sales executive  bachelors                       0      1.0
# ...

# %%
gr3 = df.groupby("company").get_group("google")
gr3
# Out:
#   company               job     degree  sallary_more_then_100k  numeric
# 0  google   sales executive  bachelors                       0      1.0
# 1  google   sales executive    masters                       0      1.0
# 2  google  business manager  bachelors                       1      1.0
# 3  google  business manager    masters                       1      1.0

# %%
df1 = pd.DataFrame({"ID": [1, 2, 3, 4],
                   "class": [9, 10, 11, 12]})
df1
# Out:
#    ID  class
# 0   1      9
# 1   2     10
# 2   3     11
# 3   4     12

# %%
df2 = pd.DataFrame({"ID": [1, 2, 3, 5],
                  "name": ["A", "B", "C", "D"]})
df2
# Out:
#    ID name
# 0   1    A
# 1   2    B
# 2   3    C
# 3   5    D

# %%
pd.merge(df1, df2, on="ID")
# Out:
#    ID  class name
# 0   1      9    A
# 1   2     10    B
# 2   3     11    C
# 3   4     12    D

# %%
pd.merge(df2, df1, on="ID")
# Out:
#    ID name  class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11
# 3   4    D     12

# %%
pd.merge(df2, df1, on="ID", how="left")
# Out:
#    ID name  class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11
# 3   4    D     12

# %%
pd.merge(df2, df1, on="ID", how="right")
# Out:
#    ID name  class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11
# 3   4  NaN     12

# %%
pd.merge(df2, df1, on="ID", how="inner")
# Out:
#    ID name  class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11

# %%
pd.merge(df2, df1, on="ID", how="outer", indicator=True)
# Out:
#    ID name  class      _merge
# 0   1    A    9.0        both
# 1   2    B   10.0        both
# 2   3    C   11.0        both
# 3   4  NaN   12.0  right_only
# 4   5    D    NaN   left_only

# %%
sr1 = pd.Series([0, 1, 2])
sr2 = pd.Series([3, 4, 5])

# %%
pd.concat([sr1, sr2])
# Out:
# 0    0
# 1    1
# 2    2
# 0    3
# 1    4
# 2    5
# dtype: int64

# %%
df2 = pd.DataFrame({"ID": [1, 2, 3, 4], "name": ['A', "B", "C", "D"], "class": [5, 6,7, 8]})
df2
# Out:
#    ID name  class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8

# %%
df3 = pd.DataFrame({"ID": [5, 6, 7, 8], "name": ['E', "F", "G", "H"], "class": [9, 10, 11, 12]})
df3
# Out:
#    ID name  class
# 0   5    E      9
# 1   6    F     10
# 2   7    G     11
# 3   8    H     12

# %%
pd.concat([df2, df3])
# Out:
#    ID name  class
# 0   5    E      9
# 1   6    F     10
# 2   7    G     11
# 3   8    H     12
# 0   5    E      9
# 1   6    F     10
# 2   7    G     11
# 3   8    H     12

# %%
pd.concat([df2, df3], axis=1) # col wise
# Out:
#    ID name  class  ID name  class
# 0   5    E      9   5    E      9
# 1   6    F     10   6    F     10
# 2   7    G     11   7    G     11
# 3   8    H     12   8    H     12

# %%
pd.concat([df2, df3], axis=0).reset_index() # row wise
# Out:
#    index  ID name  class
# 0      0   5    E      9
# 1      1   6    F     10
# 2      2   7    G     11
# 3      3   8    H     12
# 4      0   5    E      9
# 5      1   6    F     10
# 6      2   7    G     11
# 7      3   8    H     12

# %%
df1 = pd.DataFrame({"ID": [1, 2, 3, 4], "name": ['A', "B", "C", "D"], "class": [5, 6,7, 8]})
df1
# Out:
#    ID name  class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8

# %%
df2 = pd.DataFrame({"ID": [3, 4], "name": ["C", "D"], "class": [7, 8]})
df2
# Out:
#    ID name  class
# 0   3    C      7
# 1   4    D      8

# %%
pd.concat([df1, df2])
# Out:
#    ID name  class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8
# 0   3    C      7
# 1   4    D      8

# %%
pd.concat([df1, df2], axis=1)
# Out:
#    ID name  class   ID name  class
# 0   1    A      5  3.0    C    7.0
# 1   2    B      6  4.0    D    8.0
# 2   3    C      7  NaN  NaN    NaN
# 3   4    D      8  NaN  NaN    NaN

# %%
pd.concat([df1, df2], axis=1, join="inner")
# Out:
#    ID name  class  ID name  class
# 0   1    A      5   3    C      7
# 1   2    B      6   4    D      8

# %%
pd.concat([df1, df2], axis=1, keys=["df1", "df2"])
# Out:
#   df1             df2
#    ID name class   ID name class
# 0   1    A     5  3.0    C   7.0
# 1   2    B     6  4.0    D   8.0
# 2   3    C     7  NaN  NaN   NaN
# 3   4    D     8  NaN  NaN   NaN

# %%
pd.concat([df1, df2], keys=["df1", "df2"])
# Out:
#        ID name  class
# df1 0   1    A      5
#     1   2    B      6
#     2   3    C      7
#     3   4    D      8
# df2 0   3    C      7
#     1   4    D      8

# %%
df3 = pd.DataFrame({"marks": [67, 45, 99, 100]})
df3
# Out:
#    marks
# 0     67
# 1     45
# 2     99
# 3    100

# %%
pd.concat([df1, df3], axis="columns")
# Out:
#    ID name  class  marks
# 0   1    A      5     67
# 1   2    B      6     45
# 2   3    C      7     99
# 3   4    D      8    100

# %%
df1 = pd.DataFrame({"A": [1,2,3], "B": [10,20,30]})
df2 = pd.DataFrame({"A": [4,5,6], "B": [40,50,60]})

# %%
df1
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30

# %%
df2
# Out:
#    A   B
# 0  4  40
# 1  5  50
# 2  6  60

# %%
df = pd.read_excel("/content/SalaryPrediction.xlsx")
df
# Out:
#           company                  job         degree  sallary_more_then_100k  \
# 0          google      sales executive      bachelors                       0
# 1          google      sales executive        masters                       0
# 2          google     business manager      bachelors                       1
# 3          google     business manager        masters                       1
# 4             NaN  computer programmer      bachelors                       0
# 5   not available  computer programmer        masters                       1
# 6             NaN      sales executive        masters                       0
# 7             NaN  computer programmer      bachelors                       0
# 8      abc pharma     business manager            NaN                       0
# 9      abc pharma     business manager            NaN                       1
# 10       facebook      sales executive  not available                       1
# ...

# %%
df.pivot_table(index="company", values="sallary_more_then_100k", aggfunc="mean")
# Out:
#                sallary_more_then_100k
# company
# abc pharma                        0.5
# facebook                          1.0
# google                            0.5
# not available                     1.0

# %%
df.pivot_table(index="company", values="sallary_more_then_100k", aggfunc="max")
# Out:
#                sallary_more_then_100k
# company
# abc pharma                          1
# facebook                            1
# google                              1
# not available                       1

# %%
df.pivot_table(index="company", values="sallary_more_then_100k", aggfunc="min")
# Out:
#                sallary_more_then_100k
# company
# abc pharma                          0
# facebook                            1
# google                              0
# not available                       1

# %%
df.pivot_table(index="company", values="sallary_more_then_100k", aggfunc="sum")
# Out:
#                sallary_more_then_100k
# company
# abc pharma                          1
# facebook                            6
# google                              2
# not available                       1

# %%
pd.melt(df) # variable = column, value = value of columns
# Out:
#    variable   value
# 0   company  google
# 1   company  google
# 2   company  google
# 3   company  google
# 4   company     NaN
# ..      ...     ...
# 75  numeric     NaN
# 76  numeric     1.0
# 77  numeric     0.0
# 78  numeric     0.0
# 79  numeric     1.0
#
# [80 rows x 2 columns]

# %%
pd.melt(df, id_vars=["company"])
# Out:
#      company variable                value
# 0     google      job      sales executive
# 1     google      job      sales executive
# 2     google      job     business manager
# 3     google      job     business manager
# 4        NaN      job  computer programmer
# ..       ...      ...                  ...
# 59  facebook  numeric                  NaN
# 60  facebook  numeric                  1.0
# 61  facebook  numeric                  0.0
# 62  facebook  numeric                  0.0
# 63  facebook  numeric                  1.0
#
# [64 rows x 3 columns]

# %%
pd.melt(df, id_vars=["degree"], value_vars=["sallary_more_then_100k"])
# Out:
#            degree                variable  value
# 0       bachelors  sallary_more_then_100k      0
# 1         masters  sallary_more_then_100k      0
# 2       bachelors  sallary_more_then_100k      1
# 3         masters  sallary_more_then_100k      1
# 4       bachelors  sallary_more_then_100k      0
# 5         masters  sallary_more_then_100k      1
# 6         masters  sallary_more_then_100k      0
# 7       bachelors  sallary_more_then_100k      0
# 8             NaN  sallary_more_then_100k      0
# 9             NaN  sallary_more_then_100k      1
# 10  not available  sallary_more_then_100k      1
# 11            NaN  sallary_more_then_100k      1
# 12      bachelors  sallary_more_then_100k      1
# 13        masters  sallary_more_then_100k      1
# 14      bachelors  sallary_more_then_100k      1
# 15        masters  sallary_more_then_100k      1

# %%
df = pd.read_excel('/content/SalaryPrediction.xlsx', parse_dates=["date"])
df
# Out:
#           company                  job         degree  sallary_more_then_100k  \
# 0          google      sales executive      bachelors                       0
# 1          google      sales executive        masters                       0
# 2          google     business manager      bachelors                       1
# 3          google     business manager        masters                       1
# 4             NaN  computer programmer      bachelors                       0
# 5   not available  computer programmer        masters                       1
# 6             NaN      sales executive        masters                       0
# 7             NaN  computer programmer      bachelors                       0
# 8      abc pharma     business manager            NaN                       0
# 9      abc pharma     business manager            NaN                       1
# 10       facebook      sales executive  not available                       1
# ...

# %%
type(df['date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.dtypes
# Out:
# company                           object
# job                               object
# degree                            object
# sallary_more_then_100k             int64
# numeric                          float64
# date                      datetime64[ns]
# dtype: object
